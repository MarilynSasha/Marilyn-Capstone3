# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 999
from scipy import stats
np.random.seed(seed=42)
from collections import Counter
import os

# %%
#loading data 
nycdata = pd.read_csv("/Users/TheUnit/Desktop/MHA.Mock.DataSet.csv")

# %%
nycdata
# Out:
#        ID        Start time   Completion time Date of Encounter  \
# 0       3   4/29/21 7:44:56   4/29/21 9:11:58           4/22/21
# 1       4   4/29/21 9:12:29   4/29/21 9:15:04           4/29/21
# 2       5   4/29/21 9:15:48   4/29/21 9:22:21           4/29/21
# 3       6   4/29/21 9:22:24   4/29/21 9:24:47            5/6/21
# 4       7   4/29/21 9:24:52   4/29/21 9:29:21           4/29/21
# 5       8   4/29/21 9:26:29   4/29/21 9:32:20           4/29/21
# 6       9   4/29/21 9:32:22   4/29/21 9:32:37           4/29/21
# 7      10   4/29/21 9:32:39   4/29/21 9:32:52           4/29/21
# 8      11   4/29/21 9:32:57   4/29/21 9:33:11           4/29/21
# 9      12   4/29/21 9:29:23   4/29/21 9:40:26           4/29/21
# 10     13   4/29/21 9:40:25   4/29/21 9:40:42           4/29/21
# 11     14   4/29/21 9:40:45   4/29/21 9:41:02           4/29/21
# 12     15   4/29/21 9:41:04   4/29/21 9:41:17           4/29/21
# 13     16   4/29/21 9:41:18   4/29/21 9:41:31           4/29/21
# ...

# %%
nycdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 7 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  998 non-null    int64
#  1   Start time                                                          998 non-null    object
#  2   Completion time                                                     998 non-null    object
#  3   Date of Encounter                                                   998 non-null    object
#  4   Vaccination Site Name                                               998 non-null    object
#  5   Please select all that apply to your interaction with this client.  998 non-null    object
#  6   If client received 'Other' materials, please specify materials.     90 non-null     object
# ...

# %%
nycdata.columns
# Out:
# Index(['ID', 'Start time', 'Completion time', 'Date of Encounter',
#        'Vaccination Site Name',
#        'Please select all that apply to your interaction with this client.',
#        'If client received 'Other' materials, please specify materials.'],
#       dtype='object')

# %%
nycdata2 = nycdata.drop(['Start time', 'Completion time'], axis=1)

# %%
nycdata2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  998 non-null    int64
#  1   Date of Encounter                                                   998 non-null    object
#  2   Vaccination Site Name                                               998 non-null    object
#  3   Please select all that apply to your interaction with this client.  998 non-null    object
#  4   If client received 'Other' materials, please specify materials.     90 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 39.1+ KB

# %%
nycdata2
# Out:
#        ID Date of Encounter Vaccination Site Name  \
# 0       3           4/22/21                Site 2
# 1       4           4/29/21                Site 2
# 2       5           4/29/21                Site 2
# 3       6            5/6/21                Site 3
# 4       7           4/29/21                Site 3
# 5       8           4/29/21                Site 4
# 6       9           4/29/21                Site 4
# 7      10           4/29/21                Site 4
# 8      11           4/29/21                Site 4
# 9      12           4/29/21                Site 3
# 10     13           4/29/21                Site 4
# 11     14           4/29/21                Site 4
# 12     15           4/29/21                Site 4
# 13     16           4/29/21                Site 4
# 14     17           4/29/21                Site 4
# 15     18           4/29/21                Site 4
# 16     19           4/29/21                Site 4
# 17     20           4/29/21                Site 4
# ...

# %%
Q4 = nycdata2.groupby('Please select all that apply to your interaction with this client.')

# %%
Q4.first()
# Out:
#                                                      ID Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;               7           4/29/21
# Amplifier had conversation with client;Client d...  678            5/1/21
# Amplifier had conversation with client;Client r...  688            5/1/21
# Amplifier had conversation with client;Client r...  109           4/29/21
# Amplifier had conversation with client;Client r...  737            5/1/21
# Amplifier had conversation with client;Client r...  187           4/29/21
# Amplifier had conversation with client;Client r...  271           4/29/21
# Amplifier had conversation with client;Client r...  902            5/1/21
# Amplifier had conversation with client;Client r...   29           4/29/21
# Amplifier had conversation with client;Client r...  108           4/29/21
# Amplifier had conversation with client;Client r...    3           4/22/21
# ...

# %%
nycdata2['Please select all that apply to your interaction with this client.'].count()
# Out:
# 998

# %%
nycdata2.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                      ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             420                420
# Amplifier had conversation with client;Client d...    2                  2
# Amplifier had conversation with client;Client r...    3                  3
# Amplifier had conversation with client;Client r...    5                  5
# Amplifier had conversation with client;Client r...    2                  2
# Amplifier had conversation with client;Client r...    8                  8
# Amplifier had conversation with client;Client r...    2                  2
# Amplifier had conversation with client;Client r...    1                  1
# Amplifier had conversation with client;Client r...    1                  1
# Amplifier had conversation with client;Client r...   21                 21
# Amplifier had conversation with client;Client r...   11                 11
# ...

# %%
dates = nycdata2.groupby('Date of Encounter')

# %%
dates.first()
# Out:
#                     ID Vaccination Site Name  \
# Date of Encounter
# 4/22/21              3                Site 2
# 4/29/21              4                Site 2
# 4/30/21            241                Site 8
# 5/1/21             567                Site 1
# 5/6/21               6                Site 3
# 5/7/21             470                Site 1
# 5/8/21             654                Site 5
#
#                   Please select all that apply to your interaction with this client.  \
# Date of Encounter
# 4/22/21            Amplifier had conversation with client;Client ...
# 4/29/21            Amplifier had conversation with client;Client ...
# 4/30/21                      Amplifier had conversation with client;
# 5/1/21                       Amplifier had conversation with client;
# 5/6/21             Amplifier had conversation with client;Client ...
# 5/7/21                       Amplifier had conversation with client;
# ...

# %%
#creating df for dates
April22 = nycdata2[(nycdata2['Date of Encounter'] == '4/22/21') ]

# %%
April22
# Out:
#       ID Date of Encounter Vaccination Site Name  \
# 0      3           4/22/21                Site 2
# 49    52           4/22/21                Site 4
# 129  132           4/22/21                Site 4
# 221  224           4/22/21                Site 4
# 282  285           4/22/21                Site 4
#
#     Please select all that apply to your interaction with this client.  \
# 0    Amplifier had conversation with client;Client ...
# 49             Amplifier had conversation with client;
# 129            Amplifier had conversation with client;
# 221  Amplifier had conversation with client;Client ...
# 282  Amplifier had conversation with client;Client ...
#
#     If client received 'Other' materials, please specify materials.
# 0                                                  NaN
# 49                                                 NaN
# 129                                                NaN
# 221                                                NaN
# ...

# %%
April22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 282
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  5 non-null      int64
#  1   Date of Encounter                                                   5 non-null      object
#  2   Vaccination Site Name                                               5 non-null      object
#  3   Please select all that apply to your interaction with this client.  5 non-null      object
#  4   If client received 'Other' materials, please specify materials.     0 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 240.0+ bytes

# %%
April22.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              2                  2
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                 2
# Amplifier had conversation with client;Client r...                      1
# Amplifier had conversation with client;Client r...                      1
# Amplifier had conversation with client;Client r...                      1
#
#                                                     If client received 'Other' materials, please specify materials.
# ...

# %%
April30 = nycdata2[(nycdata2['Date of Encounter'] == '4/30/21') ]

# %%
April30
# Out:
#       ID Date of Encounter Vaccination Site Name  \
# 238  241           4/30/21                Site 8
# 399  402           4/30/21                Site 8
# 400  403           4/30/21                Site 4
# 401  404           4/30/21                Site 4
# 402  405           4/30/21                Site 4
# 403  406           4/30/21                Site 8
# 404  407           4/30/21                Site 7
# 405  408           4/30/21                Site 4
# 406  409           4/30/21                Site 8
# 407  410           4/30/21                Site 4
# 408  411           4/30/21                Site 8
# 409  412           4/30/21                Site 8
# 410  413           4/30/21                Site 1
# 411  414           4/30/21                Site 8
# 412  415           4/30/21                Site 7
# 413  416           4/30/21                Site 7
# 414  417           4/30/21                Site 1
# 415  418           4/30/21                Site 8
# ...

# %%
April30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163 entries, 238 to 563
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  163 non-null    int64
#  1   Date of Encounter                                                   163 non-null    object
#  2   Vaccination Site Name                                               163 non-null    object
#  3   Please select all that apply to your interaction with this client.  163 non-null    object
#  4   If client received 'Other' materials, please specify materials.     18 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 7.6+ KB

# %%
April30.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             86                 86
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...  20                 20
# Amplifier had conversation with client;Client r...  15                 15
# Amplifier had conversation with client;Client r...   4                  4
# Amplifier had conversation with client;Client r...   1                  1
# Client declined conversation but accepted flyer...   1                  1
# Client declined conversation but accepted flyer...   1                  1
# Client received NYC Care flyer;                      1                  1
# ...

# %%
#creating df for dates
April29 = nycdata2[(nycdata2['Date of Encounter'] == '4/29/21') ]

# %%
April29
# Out:
#       ID Date of Encounter Vaccination Site Name  \
# 1      4           4/29/21                Site 2
# 2      5           4/29/21                Site 2
# 4      7           4/29/21                Site 3
# 5      8           4/29/21                Site 4
# 6      9           4/29/21                Site 4
# 7     10           4/29/21                Site 4
# 8     11           4/29/21                Site 4
# 9     12           4/29/21                Site 3
# 10    13           4/29/21                Site 4
# 11    14           4/29/21                Site 4
# 12    15           4/29/21                Site 4
# 13    16           4/29/21                Site 4
# 14    17           4/29/21                Site 4
# 15    18           4/29/21                Site 4
# 16    19           4/29/21                Site 4
# 17    20           4/29/21                Site 4
# 18    21           4/29/21                Site 4
# 19    22           4/29/21                Site 4
# ...

# %%
April29.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 390 entries, 1 to 398
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  390 non-null    int64
#  1   Date of Encounter                                                   390 non-null    object
#  2   Vaccination Site Name                                               390 non-null    object
#  3   Please select all that apply to your interaction with this client.  390 non-null    object
#  4   If client received 'Other' materials, please specify materials.     22 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 18.3+ KB

# %%
April29.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                      ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             267                267
# Amplifier had conversation with client;Client r...    2                  2
# Amplifier had conversation with client;Client r...    6                  6
# Amplifier had conversation with client;Client r...    2                  2
# Amplifier had conversation with client;Client r...    1                  1
# Amplifier had conversation with client;Client r...    5                  5
# Amplifier had conversation with client;Client r...    3                  3
# Amplifier had conversation with client;Client r...    8                  8
# Amplifier had conversation with client;Client r...    5                  5
# Amplifier had conversation with client;Client r...   46                 46
# Amplifier had conversation with client;Client r...    3                  3
# ...

# %%
May1 = nycdata2[(nycdata2['Date of Encounter'] == '5/1/21')]

# %%
May1
# Out:
#        ID Date of Encounter Vaccination Site Name  \
# 564   567            5/1/21                Site 1
# 565   568            5/1/21                Site 1
# 566   569            5/1/21                Site 1
# 567   570            5/1/21                Site 1
# 568   571            5/1/21                Site 5
# 569   572            5/1/21                Site 5
# 570   573            5/1/21                Site 5
# 571   574            5/1/21                Site 5
# 572   575            5/1/21                Site 5
# 573   576            5/1/21                Site 5
# 574   577            5/1/21                Site 8
# 575   578            5/1/21                Site 6
# 576   579            5/1/21                Site 1
# 577   580            5/1/21                Site 1
# 578   581            5/1/21                Site 8
# 579   582            5/1/21                Site 5
# 580   583            5/1/21                Site 5
# 581   584            5/1/21                Site 6
# ...

# %%
May1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 433 entries, 564 to 997
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  433 non-null    int64
#  1   Date of Encounter                                                   433 non-null    object
#  2   Vaccination Site Name                                               433 non-null    object
#  3   Please select all that apply to your interaction with this client.  433 non-null    object
#  4   If client received 'Other' materials, please specify materials.     49 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 20.3+ KB

# %%
May1.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                      ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              63                 63
# Amplifier had conversation with client;Client d...    2                  2
# Amplifier had conversation with client;Client r...    3                  3
# Amplifier had conversation with client;Client r...    3                  3
# Amplifier had conversation with client;Client r...    2                  2
# Amplifier had conversation with client;Client r...    1                  1
# Amplifier had conversation with client;Client r...    1                  1
# Amplifier had conversation with client;Client r...   14                 14
# Amplifier had conversation with client;Client r...    7                  7
# Amplifier had conversation with client;Client r...    3                  3
# Amplifier had conversation with client;Client r...    6                  6
# ...

# %%
May7 = nycdata2[(nycdata2['Date of Encounter'] == '5/7/21')]

# %%
May7
# Out:
#       ID Date of Encounter Vaccination Site Name  \
# 467  470            5/7/21                Site 1
# 489  492            5/7/21                Site 8
# 559  562            5/7/21                Site 8
#
#     Please select all that apply to your interaction with this client.  \
# 467            Amplifier had conversation with client;
# 489            Amplifier had conversation with client;
# 559  Amplifier had conversation with client;Client ...
#
#     If client received 'Other' materials, please specify materials.
# 467                         Linked to NYC Well website
# 489                                                NaN
# 559                                                NaN

# %%
May7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 467 to 559
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  3 non-null      int64
#  1   Date of Encounter                                                   3 non-null      object
#  2   Vaccination Site Name                                               3 non-null      object
#  3   Please select all that apply to your interaction with this client.  3 non-null      object
#  4   If client received 'Other' materials, please specify materials.     1 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 144.0+ bytes

# %%
May7.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              2                  2
# Amplifier had conversation with client;Client r...   1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                 2
# Amplifier had conversation with client;Client r...                      1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                                             1
# Amplifier had conversation with client;Client r...                                                  0

# %%
May8 = nycdata2[(nycdata2['Date of Encounter'] == '5/8/21')]

# %%
May8
# Out:
#       ID Date of Encounter Vaccination Site Name  \
# 651  654            5/8/21                Site 5
#
#     Please select all that apply to your interaction with this client.  \
# 651  Amplifier had conversation with client;Client ...
#
#     If client received 'Other' materials, please specify materials.
# 651                                                NaN

# %%
May8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 651 to 651
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  1 non-null      int64
#  1   Date of Encounter                                                   1 non-null      object
#  2   Vaccination Site Name                                               1 non-null      object
#  3   Please select all that apply to your interaction with this client.  1 non-null      object
#  4   If client received 'Other' materials, please specify materials.     0 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 48.0+ bytes

# %%
May8.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...   1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...                      1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...                                                  0

# %%
sites = nycdata2.groupby('Vaccination Site Name')

# %%
sites.first()
# Out:
#                         ID Date of Encounter  \
# Vaccination Site Name
# Site 1                  38           4/29/21
# Site 2                   3           4/22/21
# Site 3                   6            5/6/21
# Site 4                   8           4/29/21
# Site 5                 571            5/1/21
# Site 6                 578            5/1/21
# Site 7                 407           4/30/21
# Site 8                  48           4/29/21
# Site 9                 739            5/1/21
#
#                       Please select all that apply to your interaction with this client.  \
# Vaccination Site Name
# Site 1                           Amplifier had conversation with client;
# Site 2                 Amplifier had conversation with client;Client ...
# Site 3                 Amplifier had conversation with client;Client ...
# Site 4                           Amplifier had conversation with client;
# Site 5                 Client declined conversation but accepted flye...
# ...

# %%
site1 = nycdata2[(nycdata2['Vaccination Site Name'] == 'Site 1')]

# %%
site1
# Out:
#       ID Date of Encounter Vaccination Site Name  \
# 35    38           4/29/21                Site 1
# 92    95           4/29/21                Site 1
# 94    97           4/29/21                Site 1
# 100  103           4/29/21                Site 1
# 101  104           4/29/21                Site 1
# 102  105           4/29/21                Site 1
# 103  106           4/29/21                Site 1
# 109  112           4/29/21                Site 1
# 110  113           4/29/21                Site 1
# 124  127           4/29/21                Site 1
# 128  131           4/29/21                Site 1
# 205  208           4/29/21                Site 1
# 206  209           4/29/21                Site 1
# 209  212           4/29/21                Site 1
# 220  223           4/29/21                Site 1
# 251  254           4/29/21                Site 1
# 252  255           4/29/21                Site 1
# 265  268           4/29/21                Site 1
# ...

# %%
site1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114 entries, 35 to 977
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  114 non-null    int64
#  1   Date of Encounter                                                   114 non-null    object
#  2   Vaccination Site Name                                               114 non-null    object
#  3   Please select all that apply to your interaction with this client.  114 non-null    object
#  4   If client received 'Other' materials, please specify materials.     27 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 5.3+ KB

# %%
site1.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             67                 67
# Amplifier had conversation with client;Client r...   4                  4
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   4                  4
# Amplifier had conversation with client;Client r...  17                 17
# Amplifier had conversation with client;Client r...   2                  2
# Client declined conversation but accepted flyer...   3                  3
# Client received NYC Care flyer;                      2                  2
# Client received NYC Care flyer;Amplifier had co...   1                  1
# Client received NYC Care flyer;Client refused t...   1                  1
# ...

# %%
site2 = nycdata2[(nycdata2['Vaccination Site Name'] == 'Site 2')]

# %%
site2
# Out:
#       ID Date of Encounter Vaccination Site Name  \
# 0      3           4/22/21                Site 2
# 1      4           4/29/21                Site 2
# 2      5           4/29/21                Site 2
# 851  854            5/1/21                Site 2
#
#     Please select all that apply to your interaction with this client.  \
# 0    Amplifier had conversation with client;Client ...
# 1    Amplifier had conversation with client;Client ...
# 2    Amplifier had conversation with client;Client ...
# 851            Amplifier had conversation with client;
#
#     If client received 'Other' materials, please specify materials.
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 851                                                NaN

# %%
site2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 851
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  4 non-null      int64
#  1   Date of Encounter                                                   4 non-null      object
#  2   Vaccination Site Name                                               4 non-null      object
#  3   Please select all that apply to your interaction with this client.  4 non-null      object
#  4   If client received 'Other' materials, please specify materials.     0 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 192.0+ bytes

# %%
site2.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              1                  1
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                 1
# Amplifier had conversation with client;Client r...                      2
# Amplifier had conversation with client;Client r...                      1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                                             0
# ...

# %%
site3 = nycdata2[(nycdata2['Vaccination Site Name'] == 'Site 3')]

# %%
site3
# Out:
#       ID Date of Encounter Vaccination Site Name  \
# 3      6            5/6/21                Site 3
# 4      7           4/29/21                Site 3
# 9     12           4/29/21                Site 3
# 22    25           4/29/21                Site 3
# 23    26           4/29/21                Site 3
# 33    36           4/29/21                Site 3
# 34    37           4/29/21                Site 3
# 37    40           4/29/21                Site 3
# 70    73           4/29/21                Site 3
# 75    78           4/29/21                Site 3
# 76    79           4/29/21                Site 3
# 104  107           4/29/21                Site 3
# 105  108           4/29/21                Site 3
# 107  110           4/29/21                Site 3
# 108  111           4/29/21                Site 3
# 111  114           4/29/21                Site 3
# 112  115           4/29/21                Site 3
# 137  140           4/29/21                Site 3
# ...

# %%
site3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71 entries, 3 to 985
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  71 non-null     int64
#  1   Date of Encounter                                                   71 non-null     object
#  2   Vaccination Site Name                                               71 non-null     object
#  3   Please select all that apply to your interaction with this client.  71 non-null     object
#  4   If client received 'Other' materials, please specify materials.     5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 3.3+ KB

# %%
site3.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             21                 21
# Amplifier had conversation with client;Client r...   8                  8
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...  10                 10
# Amplifier had conversation with client;Client r...   5                  5
# Amplifier had conversation with client;Client r...   1                  1
# Client received NYC Care flyer;Client received ...   1                  1
# Client received NYC Well flyer;                      1                  1
# Client refused to talk to Amplifier;                21                 21
#
#                                                     Vaccination Site Name  \
# ...

# %%
site4 = nycdata2[(nycdata2['Vaccination Site Name'] == 'Site 4')]

# %%
site4
# Out:
#       ID Date of Encounter Vaccination Site Name  \
# 5      8           4/29/21                Site 4
# 6      9           4/29/21                Site 4
# 7     10           4/29/21                Site 4
# 8     11           4/29/21                Site 4
# 10    13           4/29/21                Site 4
# 11    14           4/29/21                Site 4
# 12    15           4/29/21                Site 4
# 13    16           4/29/21                Site 4
# 14    17           4/29/21                Site 4
# 15    18           4/29/21                Site 4
# 16    19           4/29/21                Site 4
# 17    20           4/29/21                Site 4
# 18    21           4/29/21                Site 4
# 19    22           4/29/21                Site 4
# 20    23           4/29/21                Site 4
# 21    24           4/29/21                Site 4
# 24    27           4/29/21                Site 4
# 25    28           4/29/21                Site 4
# ...

# %%
site4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 318 entries, 5 to 552
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  318 non-null    int64
#  1   Date of Encounter                                                   318 non-null    object
#  2   Vaccination Site Name                                               318 non-null    object
#  3   Please select all that apply to your interaction with this client.  318 non-null    object
#  4   If client received 'Other' materials, please specify materials.     5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 14.9+ KB

# %%
site4.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                      ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             222                222
# Amplifier had conversation with client;Client r...    7                  7
# Amplifier had conversation with client;Client r...    1                  1
# Amplifier had conversation with client;Client r...    3                  3
# Amplifier had conversation with client;Client r...   12                 12
# Amplifier had conversation with client;Client r...   48                 48
# Amplifier had conversation with client;Client r...    3                  3
# Amplifier had conversation with client;Client r...    3                  3
# Amplifier had conversation with client;Client r...    3                  3
# Client declined conversation but accepted flyer...    1                  1
# Client received NY Project Hope flyer;Client re...    1                  1
# ...

# %%
site5 = nycdata2[(nycdata2['Vaccination Site Name'] == 'Site 5')]

# %%
site5
# Out:
#       ID Date of Encounter Vaccination Site Name  \
# 568  571            5/1/21                Site 5
# 569  572            5/1/21                Site 5
# 570  573            5/1/21                Site 5
# 571  574            5/1/21                Site 5
# 572  575            5/1/21                Site 5
# 573  576            5/1/21                Site 5
# 579  582            5/1/21                Site 5
# 580  583            5/1/21                Site 5
# 587  590            5/1/21                Site 5
# 588  591            5/1/21                Site 5
# 601  604            5/1/21                Site 5
# 602  605            5/1/21                Site 5
# 603  606            5/1/21                Site 5
# 625  628            5/1/21                Site 5
# 642  645            5/1/21                Site 5
# 643  646            5/1/21                Site 5
# 644  647            5/1/21                Site 5
# 651  654            5/8/21                Site 5
# ...

# %%
site5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 568 to 931
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  45 non-null     int64
#  1   Date of Encounter                                                   45 non-null     object
#  2   Vaccination Site Name                                               45 non-null     object
#  3   Please select all that apply to your interaction with this client.  45 non-null     object
#  4   If client received 'Other' materials, please specify materials.     3 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
site5.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              2                  2
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...  11                 11
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   4                  4
# Amplifier had conversation with client;Client r...   1                  1
# ...

# %%
site6 = nycdata2[(nycdata2['Vaccination Site Name'] == 'Site 6')]

# %%
site6
# Out:
#       ID Date of Encounter Vaccination Site Name  \
# 575  578            5/1/21                Site 6
# 581  584            5/1/21                Site 6
# 582  585            5/1/21                Site 6
# 583  586            5/1/21                Site 6
# 585  588            5/1/21                Site 6
# 586  589            5/1/21                Site 6
# 589  592            5/1/21                Site 6
# 590  593            5/1/21                Site 6
# 592  595            5/1/21                Site 6
# 593  596            5/1/21                Site 6
# 594  597            5/1/21                Site 6
# 597  600            5/1/21                Site 6
# 598  601            5/1/21                Site 6
# 599  602            5/1/21                Site 6
# 600  603            5/1/21                Site 6
# 605  608            5/1/21                Site 6
# 606  609            5/1/21                Site 6
# 613  616            5/1/21                Site 6
# ...

# %%
site6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157 entries, 575 to 994
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  157 non-null    int64
#  1   Date of Encounter                                                   157 non-null    object
#  2   Vaccination Site Name                                               157 non-null    object
#  3   Please select all that apply to your interaction with this client.  157 non-null    object
#  4   If client received 'Other' materials, please specify materials.     1 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 7.4+ KB

# %%
site6.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                      ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              18                 18
# Amplifier had conversation with client;Client d...    2                  2
# Amplifier had conversation with client;Client r...    1                  1
# Amplifier had conversation with client;Client r...  100                100
# Amplifier had conversation with client;Client r...    1                  1
# Amplifier had conversation with client;Client r...    1                  1
# Amplifier had conversation with client;Client r...    3                  3
# Client declined conversation but accepted flyer...    1                  1
# Client received NYC Care flyer;Amplifier had co...    1                  1
# Client received NYC Care flyer;Client received ...    6                  6
# Client received NYC Care flyer;Client received ...    3                  3
# ...

# %%
site7 = nycdata2[(nycdata2['Vaccination Site Name'] == 'Site 7')]

# %%
site7
# Out:
#       ID Date of Encounter Vaccination Site Name  \
# 404  407           4/30/21                Site 7
# 412  415           4/30/21                Site 7
# 413  416           4/30/21                Site 7
# 423  426           4/30/21                Site 7
# 428  431           4/30/21                Site 7
# 430  433           4/30/21                Site 7
# 432  435           4/30/21                Site 7
# 433  436           4/30/21                Site 7
# 437  440           4/30/21                Site 7
# 441  444           4/30/21                Site 7
# 442  445           4/30/21                Site 7
# 443  446           4/30/21                Site 7
# 444  447           4/30/21                Site 7
# 445  448           4/30/21                Site 7
# 452  455           4/30/21                Site 7
# 457  460           4/30/21                Site 7
# 458  461           4/30/21                Site 7
# 462  465           4/30/21                Site 7
# ...

# %%
site7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 404 to 787
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  38 non-null     int64
#  1   Date of Encounter                                                   38 non-null     object
#  2   Vaccination Site Name                                               38 non-null     object
#  3   Please select all that apply to your interaction with this client.  38 non-null     object
#  4   If client received 'Other' materials, please specify materials.     11 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.8+ KB

# %%
site7.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             16                 16
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   1                  1
# Client declined conversation but accepted flyer...   1                  1
# Client received NYC Well flyer;                      8                  8
# Client received NYC Well flyer;Amplifier had co...   1                  1
# Client refused to talk to Amplifier;                 4                  4
# Client refused to talk to Amplifier;Amplifier h...   2                  2
#
#                                                     Vaccination Site Name  \
# ...

# %%
site8 = nycdata2[(nycdata2['Vaccination Site Name'] == 'Site 8')]

# %%
site8
# Out:
#        ID Date of Encounter Vaccination Site Name  \
# 45     48           4/29/21                Site 8
# 46     49           4/29/21                Site 8
# 47     50           4/29/21                Site 8
# 55     58           4/29/21                Site 8
# 56     59           4/29/21                Site 8
# 61     64           4/29/21                Site 8
# 63     66           4/29/21                Site 8
# 106   109           4/29/21                Site 8
# 138   141           4/29/21                Site 8
# 139   142           4/29/21                Site 8
# 162   165           4/29/21                Site 8
# 163   166           4/29/21                Site 8
# 164   167           4/29/21                Site 8
# 165   168           4/29/21                Site 8
# 166   169           4/29/21                Site 8
# 167   170           4/29/21                Site 8
# 173   176           4/29/21                Site 8
# 178   181           4/29/21                Site 8
# ...

# %%
site8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 45 to 997
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  250 non-null    int64
#  1   Date of Encounter                                                   250 non-null    object
#  2   Vaccination Site Name                                               250 non-null    object
#  3   Please select all that apply to your interaction with this client.  250 non-null    object
#  4   If client received 'Other' materials, please specify materials.     38 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 11.7+ KB

# %%
site8.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             73                 73
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   5                  5
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   9                  9
# Amplifier had conversation with client;Client r...   4                  4
# Amplifier had conversation with client;Client r...   3                  3
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...  59                 59
# ...

# %%
site9 = nycdata2[(nycdata2['Vaccination Site Name'] == 'Site 9')]

# %%
site9
# Out:
#       ID Date of Encounter Vaccination Site Name  \
# 736  739            5/1/21                Site 9
#
#     Please select all that apply to your interaction with this client.  \
# 736               Client refused to talk to Amplifier;
#
#     If client received 'Other' materials, please specify materials.
# 736                                                NaN

# %%
site9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 736 to 736
# Data columns (total 5 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  1 non-null      int64
#  1   Date of Encounter                                                   1 non-null      object
#  2   Vaccination Site Name                                               1 non-null      object
#  3   Please select all that apply to your interaction with this client.  1 non-null      object
#  4   If client received 'Other' materials, please specify materials.     0 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 48.0+ bytes

# %%
site9.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Client refused to talk to Amplifier;                 1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Client refused to talk to Amplifier;                                    1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Client refused to talk to Amplifier;                                                                0

# %%
April22.groupby(['Vaccination Site Name']).count()
# Out:
#                        ID  Date of Encounter  \
# Vaccination Site Name
# Site 2                  1                  1
# Site 4                  4                  4
#
#                        Please select all that apply to your interaction with this client.  \
# Vaccination Site Name
# Site 2                                                                 1
# Site 4                                                                 4
#
#                        If client received 'Other' materials, please specify materials.
# Vaccination Site Name
# Site 2                                                                 0
# Site 4                                                                 0

# %%
April22.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              2                  2
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                 2
# Amplifier had conversation with client;Client r...                      1
# Amplifier had conversation with client;Client r...                      1
# Amplifier had conversation with client;Client r...                      1
#
#                                                     If client received 'Other' materials, please specify materials.
# ...

# %%
site2422 = April22[(April22['Vaccination Site Name'] == 'Site 2')]

# %%
site2422
# Out:
#    ID Date of Encounter Vaccination Site Name  \
# 0   3           4/22/21                Site 2
#
#   Please select all that apply to your interaction with this client.  \
# 0  Amplifier had conversation with client;Client ...
#
#   If client received 'Other' materials, please specify materials.
# 0                                                NaN

# %%
site2422.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...   1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...                      1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...                                                  0

# %%
site4422 = April22[(April22['Vaccination Site Name'] == 'Site 4')]

# %%
site4422
# Out:
#       ID Date of Encounter Vaccination Site Name  \
# 49    52           4/22/21                Site 4
# 129  132           4/22/21                Site 4
# 221  224           4/22/21                Site 4
# 282  285           4/22/21                Site 4
#
#     Please select all that apply to your interaction with this client.  \
# 49             Amplifier had conversation with client;
# 129            Amplifier had conversation with client;
# 221  Amplifier had conversation with client;Client ...
# 282  Amplifier had conversation with client;Client ...
#
#     If client received 'Other' materials, please specify materials.
# 49                                                 NaN
# 129                                                NaN
# 221                                                NaN
# 282                                                NaN

# %%
site4422.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              2                  2
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                 2
# Amplifier had conversation with client;Client r...                      1
# Amplifier had conversation with client;Client r...                      1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                                             0
# ...

# %%
April29.groupby(['Vaccination Site Name']).count()
# Out:
#                         ID  Date of Encounter  \
# Vaccination Site Name
# Site 1                  32                 32
# Site 2                   2                  2
# Site 3                  34                 34
# Site 4                 272                272
# Site 8                  50                 50
#
#                        Please select all that apply to your interaction with this client.  \
# Vaccination Site Name
# Site 1                                                                32
# Site 2                                                                 2
# Site 3                                                                34
# Site 4                                                               272
# Site 8                                                                50
#
#                        If client received 'Other' materials, please specify materials.
# Vaccination Site Name
# ...

# %%
site1429 = April29[(April29['Vaccination Site Name'] == 'Site 1')]

# %%
site1429.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             29                 29
# Amplifier had conversation with client;Client r...   1                  1
# Client refused to talk to Amplifier;                 2                  2
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                29
# Amplifier had conversation with client;Client r...                      1
# Client refused to talk to Amplifier;                                    2
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                                            15
# ...

# %%
site2429 = April29[(April29['Vaccination Site Name'] == 'Site 2')]

# %%
site2429.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...                      1
# Amplifier had conversation with client;Client r...                      1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...                                                  0
# Amplifier had conversation with client;Client r...                                                  0

# %%
site3429 = April29[(April29['Vaccination Site Name'] == 'Site 3')]

# %%
site3429.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              9                  9
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   3                  3
# Amplifier had conversation with client;Client r...   1                  1
# Client refused to talk to Amplifier;                20                 20
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                 9
# Amplifier had conversation with client;Client r...                      1
# Amplifier had conversation with client;Client r...                      3
# Amplifier had conversation with client;Client r...                      1
# ...

# %%
site4429 = April29[(April29['Vaccination Site Name'] == 'Site 4')]

# %%
site4429.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                      ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             199                199
# Amplifier had conversation with client;Client r...    6                  6
# Amplifier had conversation with client;Client r...    1                  1
# Amplifier had conversation with client;Client r...    2                  2
# Amplifier had conversation with client;Client r...    4                  4
# Amplifier had conversation with client;Client r...   45                 45
# Amplifier had conversation with client;Client r...    3                  3
# Amplifier had conversation with client;Client r...    3                  3
# Amplifier had conversation with client;Client r...    3                  3
# Client received NY Project Hope flyer;Client re...    1                  1
# Client refused to talk to Amplifier;                  4                  4
# ...

# %%
site8429 = April29[(April29['Vaccination Site Name'] == 'Site 8')]

# %%
site8429.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             30                 30
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   3                  3
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   1                  1
# Client received NY Project Hope flyer;               1                  1
# Client received NY Project Hope flyer;Client re...   3                  3
# Client received NYC Care flyer;Client received ...   2                  2
# Client refused to talk to Amplifier;                 2                  2
#
# ...

# %%
April30.groupby(['Vaccination Site Name']).count()
# Out:
#                        ID  Date of Encounter  \
# Vaccination Site Name
# Site 1                 19                 19
# Site 4                 42                 42
# Site 7                 37                 37
# Site 8                 65                 65
#
#                        Please select all that apply to your interaction with this client.  \
# Vaccination Site Name
# Site 1                                                                19
# Site 4                                                                42
# Site 7                                                                37
# Site 8                                                                65
#
#                        If client received 'Other' materials, please specify materials.
# Vaccination Site Name
# Site 1                                                                 7
# Site 4                                                                 0
# ...

# %%
site1430 = April30[(April30['Vaccination Site Name'] == 'Site 1')]

# %%
site1430.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             14                 14
# Amplifier had conversation with client;Client r...   4                  4
# Client refused to talk to Amplifier;                 1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                14
# Amplifier had conversation with client;Client r...                      4
# Client refused to talk to Amplifier;                                    1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                                             7
# ...

# %%
site4430 = April30[(April30['Vaccination Site Name'] == 'Site 4')]

# %%
site4430.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             21                 21
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   8                  8
# Amplifier had conversation with client;Client r...   2                  2
# Client declined conversation but accepted flyer...   1                  1
# Client received NYC Care flyer;                      1                  1
# Client received NYC Well flyer;                      3                  3
# Client refused to talk to Amplifier;                 4                  4
# Client refused to talk to Amplifier;Client rece...   1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# ...

# %%
site7430 = April30[(April30['Vaccination Site Name'] == 'Site 7')]

# %%
site7430.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             16                 16
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   1                  1
# Client declined conversation but accepted flyer...   1                  1
# Client received NYC Well flyer;                      8                  8
# Client received NYC Well flyer;Amplifier had co...   1                  1
# Client refused to talk to Amplifier;                 4                  4
# Client refused to talk to Amplifier;Amplifier h...   2                  2
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# ...

# %%
site8430 = April30[(April30['Vaccination Site Name'] == 'Site 8')]

# %%
site8430.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             35                 35
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...  19                 19
# Amplifier had conversation with client;Client r...   1                  1
# Client received NYC Care flyer;Client received ...   1                  1
# Client received NYC Care flyer;Client received ...   1                  1
# Client received NYC Care flyer;Client received ...   2                  2
# Client refused to talk to Amplifier;                 1                  1
#
#                                                     Vaccination Site Name  \
# ...

# %%
May1.groupby(['Vaccination Site Name']).count()
# Out:
#                         ID  Date of Encounter  \
# Vaccination Site Name
# Site 1                  62                 62
# Site 2                   1                  1
# Site 3                  35                 35
# Site 5                  44                 44
# Site 6                 157                157
# Site 7                   1                  1
# Site 8                 132                132
# Site 9                   1                  1
#
#                        Please select all that apply to your interaction with this client.  \
# Vaccination Site Name
# Site 1                                                                62
# Site 2                                                                 1
# Site 3                                                                35
# Site 5                                                                44
# Site 6                                                               157
# ...

# %%
site151 = May1[(May1['Vaccination Site Name'] == 'Site 1')]

# %%
site151.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             23                 23
# Amplifier had conversation with client;Client r...   3                  3
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   4                  4
# Amplifier had conversation with client;Client r...  13                 13
# Amplifier had conversation with client;Client r...   2                  2
# Client declined conversation but accepted flyer...   3                  3
# Client received NYC Care flyer;                      2                  2
# Client received NYC Care flyer;Amplifier had co...   1                  1
# Client received NYC Care flyer;Client refused t...   1                  1
# ...

# %%
site251 = May1[(May1['Vaccination Site Name'] == 'Site 2')]

# %%
site251.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                 1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                                             0

# %%
site351 = May1[(May1['Vaccination Site Name'] == 'Site 3')]

# %%
site351.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             12                 12
# Amplifier had conversation with client;Client r...   7                  7
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   6                  6
# Amplifier had conversation with client;Client r...   5                  5
# Client received NYC Care flyer;Client received ...   1                  1
# Client received NYC Well flyer;                      1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                12
# ...

# %%
site551 = May1[(May1['Vaccination Site Name'] == 'Site 5')]

# %%
site551.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              2                  2
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...  10                 10
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   4                  4
# Amplifier had conversation with client;Client r...   1                  1
# ...

# %%
site651 = May1[(May1['Vaccination Site Name'] == 'Site 6')]

# %%
site651.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                      ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              18                 18
# Amplifier had conversation with client;Client d...    2                  2
# Amplifier had conversation with client;Client r...    1                  1
# Amplifier had conversation with client;Client r...  100                100
# Amplifier had conversation with client;Client r...    1                  1
# Amplifier had conversation with client;Client r...    1                  1
# Amplifier had conversation with client;Client r...    3                  3
# Client declined conversation but accepted flyer...    1                  1
# Client received NYC Care flyer;Amplifier had co...    1                  1
# Client received NYC Care flyer;Client received ...    6                  6
# Client received NYC Care flyer;Client received ...    3                  3
# ...

# %%
site751 = May1[(May1['Vaccination Site Name'] == 'Site 7')]

# %%
site751.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...   1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...                      1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...                                                  0

# %%
site851 = May1[(May1['Vaccination Site Name'] == 'Site 8')]

# %%
site851.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              7                  7
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   3                  3
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   4                  4
# Amplifier had conversation with client;Client r...   2                  2
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...   1                  1
# Amplifier had conversation with client;Client r...  38                 38
# Amplifier had conversation with client;Client r...   3                  3
# ...

# %%
site951 = May1[(May1['Vaccination Site Name'] == 'Site 9')]

# %%
site951.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Client refused to talk to Amplifier;                 1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Client refused to talk to Amplifier;                                    1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Client refused to talk to Amplifier;                                                                0

# %%
May7.groupby(['Vaccination Site Name']).count()
# Out:
#                        ID  Date of Encounter  \
# Vaccination Site Name
# Site 1                  1                  1
# Site 8                  2                  2
#
#                        Please select all that apply to your interaction with this client.  \
# Vaccination Site Name
# Site 1                                                                 1
# Site 8                                                                 2
#
#                        If client received 'Other' materials, please specify materials.
# Vaccination Site Name
# Site 1                                                                 1
# Site 8                                                                 0

# %%
May7.groupby(['Vaccination Site Name']).count()
# Out:
#                        ID  Date of Encounter  \
# Vaccination Site Name
# Site 1                  1                  1
# Site 8                  2                  2
#
#                        Please select all that apply to your interaction with this client.  \
# Vaccination Site Name
# Site 1                                                                 1
# Site 8                                                                 2
#
#                        If client received 'Other' materials, please specify materials.
# Vaccination Site Name
# Site 1                                                                 1
# Site 8                                                                 0

# %%
site157 = May7[(May7['Vaccination Site Name'] == 'Site 1')]

# %%
site157.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                 1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                                             1

# %%
nycdata33.groupby(['Vaccination Site Name']).count()

# %%
site857.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              1                  1
# Amplifier had conversation with client;Client r...   1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                 1
# Amplifier had conversation with client;Client r...                      1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                                             0
# Amplifier had conversation with client;Client r...                                                  0

# %%
May8.groupby(['Vaccination Site Name']).count()
# Out:
#                        ID  Date of Encounter  \
# Vaccination Site Name
# Site 5                  1                  1
#
#                        Please select all that apply to your interaction with this client.  \
# Vaccination Site Name
# Site 5                                                                 1
#
#                        If client received 'Other' materials, please specify materials.
# Vaccination Site Name
# Site 5                                                                 0

# %%
May8.groupby(['Vaccination Site Name']).count()
# Out:
#                        ID  Date of Encounter  \
# Vaccination Site Name
# Site 5                  1                  1
#
#                        Please select all that apply to your interaction with this client.  \
# Vaccination Site Name
# Site 5                                                                 1
#
#                        If client received 'Other' materials, please specify materials.
# Vaccination Site Name
# Site 5                                                                 0

# %%
site558 = May8[(May8['Vaccination Site Name'] == 'Site 5')]

# %%
site558.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...   1                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...                      1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...                                                  0

# %%
wk1 = (nycdata['Date of Encounter'] >'4/22/21') & (nycdata['Date of Encounter'] <= '4/22/21')

# %%
nycdata33 = nycdata.loc[wk1]

# %%
display(nycdata33)
# Out:
# Empty DataFrame
# Columns: [ID, Start time, Completion time, Date of Encounter, Vaccination Site Name, Please select all that apply to your interaction with this client., If client received 'Other' materials, please specify materials.]
# Index: []

# %%
nycdata33.groupby(['Vaccination Site Name']).count()
# Out:
# Empty DataFrame
# Columns: [ID, Start time, Completion time, Date of Encounter, Please select all that apply to your interaction with this client., If client received 'Other' materials, please specify materials.]
# Index: []

# %%
nycdata33.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
# Empty DataFrame
# Columns: [ID, Start time, Completion time, Date of Encounter, Vaccination Site Name, If client received 'Other' materials, please specify materials.]
# Index: []

# %%
nycdata33.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 7 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  0 non-null      int64
#  1   Start time                                                          0 non-null      object
#  2   Completion time                                                     0 non-null      object
#  3   Date of Encounter                                                   0 non-null      object
#  4   Vaccination Site Name                                               0 non-null      object
#  5   Please select all that apply to your interaction with this client.  0 non-null      object
#  6   If client received 'Other' materials, please specify materials.     0 non-null      object
# ...

# %%
wk2 = (nycdata['Date of Encounter'] >'4/29/21') & (nycdata['Date of Encounter'] <= '5/2/21')

# %%
nycdata32 = nycdata.loc[wk2]

# %%
display(nycdata32)
# Out:
#        ID        Start time   Completion time Date of Encounter  \
# 238   241  4/29/21 14:35:14  4/29/21 14:35:45           4/30/21
# 399   402   4/30/21 9:00:51   4/30/21 9:05:23           4/30/21
# 400   403   4/30/21 8:26:58   4/30/21 9:17:50           4/30/21
# 401   404   4/30/21 9:29:04   4/30/21 9:32:06           4/30/21
# 402   405   4/30/21 9:32:08   4/30/21 9:33:17           4/30/21
# 403   406   4/30/21 9:05:25   4/30/21 9:33:32           4/30/21
# 404   407   4/30/21 9:30:57   4/30/21 9:33:59           4/30/21
# 405   408   4/30/21 9:33:18   4/30/21 9:45:09           4/30/21
# 406   409   4/30/21 9:33:35   4/30/21 9:45:37           4/30/21
# 407   410   4/30/21 9:45:30   4/30/21 9:51:10           4/30/21
# 408   411   4/30/21 8:50:37   4/30/21 9:55:16           4/30/21
# 409   412   4/30/21 9:45:40  4/30/21 10:03:22           4/30/21
# 410   413  4/30/21 10:09:10  4/30/21 10:09:48           4/30/21
# 411   414   4/30/21 9:55:18  4/30/21 10:11:35           4/30/21
# ...

# %%
nycdata32.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 596 entries, 238 to 997
# Data columns (total 7 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  596 non-null    int64
#  1   Start time                                                          596 non-null    object
#  2   Completion time                                                     596 non-null    object
#  3   Date of Encounter                                                   596 non-null    object
#  4   Vaccination Site Name                                               596 non-null    object
#  5   Please select all that apply to your interaction with this client.  596 non-null    object
#  6   If client received 'Other' materials, please specify materials.     67 non-null     object
# ...

# %%
nycdata32.groupby(['Vaccination Site Name']).count()
# Out:
#                         ID  Start time  Completion time  Date of Encounter  \
# Vaccination Site Name
# Site 1                  81          81               81                 81
# Site 2                   1           1                1                  1
# Site 3                  35          35               35                 35
# Site 4                  42          42               42                 42
# Site 5                  44          44               44                 44
# Site 6                 157         157              157                157
# Site 7                  38          38               38                 38
# Site 8                 197         197              197                197
# Site 9                   1           1                1                  1
#
#                        Please select all that apply to your interaction with this client.  \
# Vaccination Site Name
# Site 1                                                                81
# ...

# %%
wk21 = nycdata32[(nycdata32['Vaccination Site Name'] == 'Site 1')]

# %%
wk21.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Start time  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             37          37
# Amplifier had conversation with client;Client r...   3           3
# Amplifier had conversation with client;Client r...   1           1
# Amplifier had conversation with client;Client r...   1           1
# Amplifier had conversation with client;Client r...   4           4
# Amplifier had conversation with client;Client r...  17          17
# Amplifier had conversation with client;Client r...   2           2
# Client declined conversation but accepted flyer...   3           3
# Client received NYC Care flyer;                      2           2
# Client received NYC Care flyer;Amplifier had co...   1           1
# Client received NYC Care flyer;Client refused t...   1           1
# Client received NYC Well flyer;Client received ...   3           3
# ...

# %%
wk22 = nycdata32[(nycdata32['Vaccination Site Name'] == 'Site 2')]

# %%
wk22.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Start time  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              1           1
#
#                                                     Completion time  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                           1
#
#                                                     Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                             1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                                 1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# ...

# %%
wk23 = nycdata32[(nycdata32['Vaccination Site Name'] == 'Site 3')]

# %%
wk23.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Start time  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             12          12
# Amplifier had conversation with client;Client r...   7           7
# Amplifier had conversation with client;Client r...   2           2
# Amplifier had conversation with client;Client r...   1           1
# Amplifier had conversation with client;Client r...   6           6
# Amplifier had conversation with client;Client r...   5           5
# Client received NYC Care flyer;Client received ...   1           1
# Client received NYC Well flyer;                      1           1
#
#                                                     Completion time  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                          12
# Amplifier had conversation with client;Client r...                7
# ...

# %%
wk24 = nycdata32[(nycdata32['Vaccination Site Name'] == 'Site 4')]

# %%
wk24.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Start time  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             21          21
# Amplifier had conversation with client;Client r...   1           1
# Amplifier had conversation with client;Client r...   8           8
# Amplifier had conversation with client;Client r...   2           2
# Client declined conversation but accepted flyer...   1           1
# Client received NYC Care flyer;                      1           1
# Client received NYC Well flyer;                      3           3
# Client refused to talk to Amplifier;                 4           4
# Client refused to talk to Amplifier;Client rece...   1           1
#
#                                                     Completion time  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;                          21
# ...

# %%
wk25 = nycdata32[(nycdata32['Vaccination Site Name'] == 'Site 5')]

# %%
wk25.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Start time  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              2           2
# Amplifier had conversation with client;Client r...   1           1
# Amplifier had conversation with client;Client r...   1           1
# Amplifier had conversation with client;Client r...   1           1
# Amplifier had conversation with client;Client r...   2           2
# Amplifier had conversation with client;Client r...  10          10
# Amplifier had conversation with client;Client r...   1           1
# Amplifier had conversation with client;Client r...   1           1
# Amplifier had conversation with client;Client r...   2           2
# Amplifier had conversation with client;Client r...   4           4
# Amplifier had conversation with client;Client r...   1           1
# Client declined conversation but accepted flyer...   1           1
# ...

# %%
wk26 = nycdata32[(nycdata32['Vaccination Site Name'] == 'Site 6')]

# %%
wk26.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                      ID  Start time  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;              18          18
# Amplifier had conversation with client;Client d...    2           2
# Amplifier had conversation with client;Client r...    1           1
# Amplifier had conversation with client;Client r...  100         100
# Amplifier had conversation with client;Client r...    1           1
# Amplifier had conversation with client;Client r...    1           1
# Amplifier had conversation with client;Client r...    3           3
# Client declined conversation but accepted flyer...    1           1
# Client received NYC Care flyer;Amplifier had co...    1           1
# Client received NYC Care flyer;Client received ...    6           6
# Client received NYC Care flyer;Client received ...    3           3
# Client refused to talk to Amplifier;                 20          20
#
# ...

# %%
wk27 = nycdata32[(nycdata32['Vaccination Site Name'] == 'Site 7')]

# %%
wk27.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Start time  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             16          16
# Amplifier had conversation with client;Client r...   1           1
# Amplifier had conversation with client;Client r...   2           2
# Amplifier had conversation with client;Client r...   2           2
# Amplifier had conversation with client;Client r...   1           1
# Client declined conversation but accepted flyer...   1           1
# Client received NYC Well flyer;                      8           8
# Client received NYC Well flyer;Amplifier had co...   1           1
# Client refused to talk to Amplifier;                 4           4
# Client refused to talk to Amplifier;Amplifier h...   2           2
#
#                                                     Completion time  \
# Please select all that apply to your interactio...
# ...

# %%
wk28 = nycdata32[(nycdata32['Vaccination Site Name'] == 'Site 8')]

# %%
wk28.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Start time  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;             42          42
# Amplifier had conversation with client;Client r...   2           2
# Amplifier had conversation with client;Client r...   3           3
# Amplifier had conversation with client;Client r...   1           1
# Amplifier had conversation with client;Client r...   1           1
# Amplifier had conversation with client;Client r...   6           6
# Amplifier had conversation with client;Client r...   2           2
# Amplifier had conversation with client;Client r...   3           3
# Amplifier had conversation with client;Client r...   2           2
# Amplifier had conversation with client;Client r...  57          57
# Amplifier had conversation with client;Client r...   4           4
# Amplifier had conversation with client;Client r...   3           3
# ...

# %%
wk29 = nycdata32[(nycdata32['Vaccination Site Name'] == 'Site 9')]

# %%
wk29.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Start time  \
# Please select all that apply to your interactio...
# Client refused to talk to Amplifier;                 1           1
#
#                                                     Completion time  \
# Please select all that apply to your interactio...
# Client refused to talk to Amplifier;                              1
#
#                                                     Date of Encounter  \
# Please select all that apply to your interactio...
# Client refused to talk to Amplifier;                                1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Client refused to talk to Amplifier;                                    1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# ...

# %%
wk3 = (nycdata['Date of Encounter'] >'5/7/21') & (nycdata['Date of Encounter'] <= '5/8/21')

# %%
nycdata31 = nycdata.loc[wk3]

# %%
display(nycdata31)
# Out:
#       ID       Start time  Completion time Date of Encounter  \
# 651  654  5/1/21 11:25:08  5/1/21 11:25:46            5/8/21
#
#     Vaccination Site Name  \
# 651                Site 5
#
#     Please select all that apply to your interaction with this client.  \
# 651  Amplifier had conversation with client;Client ...
#
#     If client received 'Other' materials, please specify materials.
# 651                                                NaN

# %%
nycdata31.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 651 to 651
# Data columns (total 7 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  1 non-null      int64
#  1   Start time                                                          1 non-null      object
#  2   Completion time                                                     1 non-null      object
#  3   Date of Encounter                                                   1 non-null      object
#  4   Vaccination Site Name                                               1 non-null      object
#  5   Please select all that apply to your interaction with this client.  1 non-null      object
#  6   If client received 'Other' materials, please specify materials.     0 non-null      object
# ...

# %%
nycdata31.groupby(['Please select all that apply to your interaction with this client.']).count()
# Out:
#                                                     ID  Start time  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...   1           1
#
#                                                     Completion time  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...                1
#
#                                                     Date of Encounter  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...                  1
#
#                                                     Vaccination Site Name  \
# Please select all that apply to your interactio...
# Amplifier had conversation with client;Client r...                      1
#
#                                                     If client received 'Other' materials, please specify materials.
# Please select all that apply to your interactio...
# ...

# %%
nycdata31.groupby(['Vaccination Site Name']).count()
# Out:
#                        ID  Start time  Completion time  Date of Encounter  \
# Vaccination Site Name
# Site 5                  1           1                1                  1
#
#                        Please select all that apply to your interaction with this client.  \
# Vaccination Site Name
# Site 5                                                                 1
#
#                        If client received 'Other' materials, please specify materials.
# Vaccination Site Name
# Site 5                                                                 0
